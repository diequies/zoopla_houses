# %% [markdown]
# # Zoopla Data Ingestion
#
# The purpose of this Notebook is to extract and wrangle zoopla data to finally input in a SQL file for further analysis.
#
# Within the Notebook there are several steps:
#
# 1. Extract the basic information and individual link for all the search pages of each borough search.
# 2. Scrape the JSON file of each individual house and parse it to extract the interesting information.
# 3. Wrangle the data to get an structured DataFrame.
# 4. Extract from the text features as much information as possible.
# 5. Drop the useless features.
# 6. Drop the records with not enough data.
# 7. Save the database in a SQL server.

# %%
import requests
from bs4 import BeautifulSoup as soup
import numpy as np
import pandas as pd
import math
import json
import time
import re
from datetime import datetime, date, timedelta
from DataIngestZoopla import number_of_search_pages
from DataIngestZoopla import get_borough_url
from DataIngestZoopla import get_main_house_details
from DataIngestZoopla import get_house_inner_details
from DataIngestZoopla import sq_m_features_find
from DataIngestZoopla import sq_ft_features_find
from DataIngestZoopla import extract_feature
import ast
import mysql.connector
from mysql.connector import Error
from sqlalchemy import create_engine
import MySQLdb

# %% [markdown]
# ## 1. Basic information extraction
#
# First I load the list of London Boroughs and the keys to make the search links.
#
# As the search links had not a complete sense, I preferred to create them manually.

# %%
df_boroughs = pd.read_csv('list_of_boroughs.csv')

# %% [markdown]
# Then using the custom functions get_borough_url and number_of_search_pages I extract the links and number of pages for each page in each borough search.

# %%
df_boroughs = pd.DataFrame(df_dict)
df_boroughs['borough_url'] = df_boroughs.apply(lambda x: get_borough_url(x['london_brough_links_1']\
                                                                         ,x['london_brough_links_2']), 
                                               axis = 1)
df_boroughs[['pages','house_num']] = df_boroughs['borough_url'].apply(lambda x: number_of_search_pages(x))
df_boroughs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-6298c75b4000> in <module>
# ----> 1 df_boroughs = pd.DataFrame(df_dict)
#       2 df_boroughs['borough_url'] = df_boroughs.apply(lambda x: get_borough_url(x['london_brough_links_1']\
#       3                                                                          ,x['london_brough_links_2']),
#       4                                                axis = 1)
#       5 df_boroughs[['pages','house_num']] = df_boroughs['borough_url'].apply(lambda x: number_of_search_pages(x))
#
# NameError: name 'df_dict' is not defined

# %% [markdown]
# Using the list of boroughs with its link for the first search page I use the custom function get_main_house_details to scrape from each search page the link and listed date of each house.
#
# As there are many old ads, I filter to get just the ones less than 6 months old.

# %%
for i in range(0,df_boroughs.shape[0]):
    data_link, data_listed = get_main_house_details(df_boroughs['borough_url'][i],df_boroughs['pages'][i],
                                                    df_boroughs['house_num'][i])
    print(len(data_link))
    if i == 0:
        df_houses = pd.DataFrame({'Link':data_link,'Listed':data_listed},
                     columns = ['Link','Listed'])
        df_houses['Borough'] = df_boroughs['borough_name'][i]
    else:
        df_houses_temp = pd.DataFrame({'Link':data_link,'Listed':data_listed},
                     columns = ['Link','Listed'])
        df_houses_temp['Borough'] = df_boroughs['borough_name'][i]
        df_houses = df_houses.append(df_houses_temp)
        
df_houses['date_listed'] = df_houses['Listed'].apply(lambda x: datetime.strptime(x.split(' ')[-3][:-2]\
                                                                                 + '-' + x.split(' ')[-2]\
                                                                                 + '-' + x.split(' ')[-1],
                                                                                 '%d-%b-%Y'))
df_houses_to_get = df_houses[df_houses['date_listed'] > pd.to_datetime(date.today() - timedelta(days=180))]
# 46                         Arkwright Road, London NW3             False
# 47            Chalcot Road, Primrose Hill, London NW1             False
# 48                        Phoenix Street, London WC2H             False
# 49          Winchester Road, Belsize Park, London NW3             False
# 50            St. Cuthbert's Road, West Hampstead NW2             False
# 51        Primrose Gardens, Belsize Park NW3, London,             False
# 52                           Fetter Lane, London EC4A             False
# 53                      57A Lisson Street, London NW1             False
# 54                          Finchley Road, London NW3             False
# 55                            Platts Lane, London NW3             False
# 56                 Lymington Road, West Hampstead NW6             False
# 57         University Street, Bloomsbury, London WC1E             False
# 58          Heathway Court, Finchley Road, London NW3             False
# 59               Mornington Crescent, Camden Town NW1             False
#
#     isSharedOwnership  ...                                     firstPublished  \
# 0               False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 1               False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 2               False  ...                                               None
# 3               False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 4               False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 5               False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 6               False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 7               False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 8               False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 9               False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 10              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 11              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 12              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 13              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 14              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 15              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 16              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 17              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 18              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 19              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 20              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 21              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 22              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 23              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 24              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 25              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 26              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 27              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 28              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 29              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 30              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 31              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 32              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 33              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 34              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 35              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 36              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 37              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 38              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 39              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 40              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 41              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 42              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 43              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 44              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 45              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 46              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 47              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 48              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 49              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 50              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 51              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 52              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 53              False  ...                                               None
# 54              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 55              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 56              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 57              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 58              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
# 59              False  ...  {'__typename': 'PriceHistoryFirstPublished', '...
#
#                                              lastSale   firstPublishedDate  \
# 0                                                None  2021-06-26 16:52:13
# 1                                                None  2021-06-26 11:32:09
# 2                                                None                 None
# 3                                                None  2021-06-26 00:05:11
# 4   {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 23:35:16
# 5                                                None  2021-06-25 22:01:56
# 6                                                None  2021-06-25 19:47:54
# 7   {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 19:21:38
# 8                                                None  2021-06-25 18:13:10
# 9                                                None  2021-06-25 18:07:40
# 10                                               None  2021-06-25 18:06:16
# 11                                               None  2021-06-25 18:06:16
# 12                                               None  2021-06-25 17:57:03
# 13  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 16:58:22
# 14                                               None  2021-06-25 16:51:04
# 15  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 16:34:18
# 16  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 16:22:16
# 17                                               None  2021-06-25 15:57:41
# 18                                               None  2021-06-25 15:41:11
# 19                                               None  2021-06-25 15:27:32
# 20  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 15:00:32
# 21                                               None  2021-06-25 14:51:13
# 22                                               None  2021-06-25 14:31:46
# 23  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 14:07:59
# 24                                               None  2021-06-25 14:06:34
# 25                                               None  2021-06-25 14:05:22
# 26                                               None  2021-06-25 14:00:33
# 27                                               None  2021-06-25 13:55:33
# 28                                               None  2021-06-25 13:49:20
# 29  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 13:34:56
# 30  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 12:57:19
# 31                                               None  2021-06-25 12:49:09
# 32                                               None  2021-06-25 12:29:25
# 33  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 12:17:38
# 34                                               None  2021-06-25 12:03:54
# 35  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 10:28:11
# 36  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-25 10:19:36
# 37                                               None  2021-06-25 09:35:30
# 38                                               None  2021-06-24 22:03:50
# 39                                               None  2021-06-24 21:18:57
# 40  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-24 19:45:18
# 41                                               None  2021-06-24 18:04:32
# 42                                               None  2021-06-24 17:12:45
# 43                                               None  2021-06-24 16:50:11
# 44                                               None  2021-06-24 16:27:41
# 45                                               None  2021-06-24 16:02:44
# 46  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-24 15:32:16
# 47                                               None  2021-06-24 15:16:47
# 48                                               None  2021-06-24 15:08:08
# 49  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-24 15:03:34
# 50  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-24 14:51:31
# 51                                               None  2021-06-24 14:10:04
# 52                                               None  2021-06-24 13:54:32
# 53                                               None                 None
# 54  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-24 11:56:11
# 55                                               None  2021-06-24 11:33:51
# 56  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-24 10:47:52
# 57                                               None  2021-06-24 09:01:40
# 58  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-24 08:36:17
# 59  {'__typename': 'PriceHistoryLastSale', 'date':...  2021-06-24 08:25:34
#
#     firstPublishedPrice lastSaleDate  lastSaleNewBuild lastSalePrice  \
# 0              285000.0         None              None           NaN
# 1             1150000.0         None              None           NaN
# 2                   NaN         None              None           NaN
# 3              850000.0         None              None           NaN
# 4             1100000.0   2017-10-13             False      655000.0
# 5             2350000.0         None              None           NaN
# 6             1250000.0         None              None           NaN
# 7             1350000.0   1996-01-22             False      209000.0
# 8             1200000.0         None              None           NaN
# 9              575000.0         None              None           NaN
# 10             775000.0         None              None           NaN
# 11             799950.0         None              None           NaN
# 12             625000.0         None              None           NaN
# 13             500000.0   2019-02-11             False      665000.0
# 14            1450000.0         None              None           NaN
# 15             475000.0   2013-10-18             False      380000.0
# 16             775000.0   2004-07-14             False      280000.0
# 17             400000.0         None              None           NaN
# 18             550000.0         None              None           NaN
# 19             580000.0         None              None           NaN
# 20             595000.0   1997-09-12             False       98000.0
# 21            2500000.0         None              None           NaN
# 22            1450000.0         None              None           NaN
# 23             425000.0   2001-02-16             False      135000.0
# 24             620000.0         None              None           NaN
# 25             525000.0         None              None           NaN
# 26             510000.0         None              None           NaN
# 27             500000.0         None              None           NaN
# 28            7750000.0         None              None           NaN
# 29            1495000.0   2020-01-10             False     1207000.0
# 30             900000.0   2014-08-19             False      795000.0
# 31             485000.0         None              None           NaN
# 32             700000.0         None              None           NaN
# 33             550000.0   2011-08-08             False      244000.0
# 34             835000.0         None              None           NaN
# 35            1750000.0   2005-12-01             False      670000.0
# 36            2500000.0   2005-07-29             False      340000.0
# 37            1599950.0         None              None           NaN
# 38             825000.0         None              None           NaN
# 39             275000.0         None              None           NaN
# 40             565000.0   2012-02-10             False      315000.0
# 41             699995.0         None              None           NaN
# 42             450000.0         None              None           NaN
# 43             500000.0         None              None           NaN
# 44             450000.0         None              None           NaN
# 45             625000.0         None              None           NaN
# 46             950000.0   2008-05-01             False      550000.0
# 47            1500000.0         None              None           NaN
# 48            1499000.0         None              None           NaN
# 49            1800000.0   2018-10-11             False     1315000.0
# 50             449000.0   2018-08-17             False      700000.0
# 51             875000.0         None              None           NaN
# 52            1499000.0         None              None           NaN
# 53                  NaN         None              None           NaN
# 54            1450000.0   2016-01-05             False     1000000.0
# 55            1200000.0         None              None           NaN
# 56             700000.0   2015-11-13             False      699950.0
# 57             690000.0         None              None           NaN
# 58             499999.0   2015-10-09             False      400000.0
# 59             480000.0   2017-10-27             False      470000.0
#
#                        sq_ft sq_ft_num sq_m_feat
# 0                       None      None       NaN
# 1            [over 1400sqft]      1400     130.0
# 2                       None      None       NaN
# 3                       None      None       NaN
# 4                       None      None       NaN
# 5                       None      None       NaN
# 6               [1171 sq ft]      1171     109.0
# 7                       None      None       NaN
# 8                       None      None       NaN
# 9                       None      None       NaN
# 10                      None      None       NaN
# 11                      None      None       NaN
# 12                      None      None       NaN
# 13                      None      None       NaN
# 14                      None      None       NaN
# 15                      None      None       NaN
# 16                      None      None       NaN
# 17                      None      None       NaN
# 18                      None      None       NaN
# 19                      None      None       NaN
# 20                      None      None       NaN
# 21                      None      None       NaN
# 22                      None      None       NaN
# 23                      None      None       NaN
# 24                      None      None       NaN
# 25                      None      None       NaN
# 26                      None      None       NaN
# 27                      None      None       NaN
# 28                      None      None       NaN
# 29                      None      None       NaN
# 30  [1069 sq ft / 99.3 sq m]      1069      99.0
# 31                      None      None       NaN
# 32                      None      None       NaN
# 33                      None      None       NaN
# 34                      None      None       NaN
# 35                      None      None       NaN
# 36                      None      None       NaN
# 37                      None      None       NaN
# 38                      None      None       NaN
# 39                      None      None       NaN
# 40                      None      None       NaN
# 41                      None      None       NaN
# 42                      None      None       NaN
# 43                      None      None       NaN
# 44                      None      None       NaN
# 45                      None      None       NaN
# 46                      None      None       NaN
# 47                      None      None       NaN
# 48                      None      None       NaN
# 49                      None      None       NaN
# 50                      None      None       NaN
# 51                      None      None       NaN
# 52   [1352 sq ft - 126 sq m]      1352     126.0
# 53                      None      None       NaN
# 54                      None      None       NaN
# 55                      None      None       NaN
# 56                      None      None       NaN
# 57                      None      None       NaN
# 58                      None      None       NaN
# 59                      None      None       NaN
#
# [60 rows x 42 columns]

# %% [markdown]
# ## 3. Data Wrangling
#
# The first item of data wrangling is to extract and convert the floor area from its dictionary and convert to m^2 if necessary.

# %%
df_houses_wrangling['floorArea'].fillna(value = np.nan, inplace = True)
df_houses_wrangling['floor_area_amount'] = df_houses_wrangling['floorArea'].apply(lambda x: None if 
                                                                                  pd.isnull(x) 
                                                                        else eval(x)['value'])
df_houses_wrangling['floor_area_units'] = df_houses_wrangling['floorArea'].apply(lambda x: None if 
                                                                                  pd.isnull(x) 
                                                                        else eval(x)['unitsLabel'])
df_houses_wrangling['floor_area_msq'] = df_houses_wrangling.apply(lambda x: None if 
                                                                  pd.isnull(x['floor_area_amount']) else
                                                                  ((round(x['floor_area_amount']/10.7639)) 
                                                                  if (x['floor_area_units'] == 'sq. ft') 
                                                                  else x['floor_area_amount']), axis = 1)

# %% [markdown]
# Now, to extract some basic information such as amount of beds, baths, etc. from its dictionary.

# %%
# temporally to delete empty lines
df_houses_wrangling.drop(df_houses_wrangling[df_houses_wrangling['RoomCount'].isnull()].index, 
                         inplace = True, axis = 0)
df_houses_wrangling[df_houses_wrangling['RoomCount'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Link, Listed, Borough, date_listed, agency_name, agency_phone, chain_free, address, isRetirementHome, isSharedOwnership, listingCondition, listingStatus, RoomCount, price, propertyType, isAuction, priceHistory, floorArea, tenure, detailedDescription, features, furnishedState, title, latitude, longitude, statusSummary, floor_area_amount, floor_area_units, floor_area_msq]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_houses_wrangling['numBedrooms'] = df_houses_wrangling['RoomCount'].apply(lambda x: 0\
                                                  if pd.isnull(ast.literal_eval(x)['numBedrooms']) 
                                                                        else ast.literal_eval(x)['numBedrooms'])
df_houses_wrangling['numBathrooms'] = df_houses_wrangling['RoomCount'].apply(lambda x: 0\
                                                  if pd.isnull(ast.literal_eval(x)['numBathrooms']) 
                                                                        else ast.literal_eval(x)['numBathrooms'])
df_houses_wrangling['numLivingRooms'] = df_houses_wrangling['RoomCount'].apply(lambda x: 0\
                                                  if pd.isnull(ast.literal_eval(x)['numLivingRooms']) 
                                                                        else ast.literal_eval(x)['numLivingRooms'])

# %% [markdown]
# Next step is to extract historical information. In this case the dictionary varies depending on the information available, so it is important to avoid errors trying to use None values.

# %%
df_houses_wrangling['firstPublished'] = df_houses_wrangling['priceHistory'].apply(lambda x: None if 
                                                                                  pd.isnull(x) 
                                                                        else eval(x)['firstPublished'])
df_houses_wrangling['lastSale'] = df_houses_wrangling['priceHistory'].apply(lambda x: None if 
                                                                            pd.isnull(x) 
                                                                            else ast.literal_eval(x)['lastSale'])
df_houses_wrangling['firstPublishedDate'] = df_houses_wrangling['firstPublished'].apply(lambda x: None if 
                                                                                    pd.isnull(x) 
                                                                    else x['firstPublishedDate'])
df_houses_wrangling['firstPublishedPrice'] = df_houses_wrangling['firstPublished'].apply(lambda x: None 
                                                                                if pd.isnull(x) 
                                                                            else x['priceLabel'])
df_houses_wrangling['lastSaleDate'] = df_houses_wrangling['lastSale'].apply(lambda x: None 
                                                                            if pd.isnull(x) 
                                                                            else x['date'])
df_houses_wrangling['lastSaleNewBuild'] = df_houses_wrangling['lastSale'].apply(lambda x: None 
                                                                                if pd.isnull(x) 
                                                                            else x['newBuild'])
df_houses_wrangling['lastSalePrice'] = df_houses_wrangling['lastSale'].apply(lambda x: None 
                                                                             if pd.isnull(x) 
                                                                             else x['price'])
df_houses_wrangling['firstPublishedPrice'] = df_houses_wrangling['firstPublishedPrice'].apply(lambda x:None 
                                                                                              if pd.isnull(x)\
                                                                 else int(x.replace(',','').split('£')[-1]))

# %% [markdown]
# ## 4. Feature Extraction

# %% [markdown]
# From features data we can try to extract floor are information, as currently this feature is full of empty records but it is very important.
#
# I will use the functions I created to extract any feature that contains the words sq ft or sq m in some way.

# %%
df_houses_wrangling['sq_m_feat_from_ft'] = df_houses_wrangling['features'].apply(lambda x: None if pd.isnull(x)
                                                                                else sq_ft_features_find(x))

df_houses_wrangling['sq_m_feat_from_m'] = df_houses_wrangling['features'].apply(lambda x: None if pd.isnull(x)
                                                                                else sq_m_features_find(x))

# %%
df_houses_wrangling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50675 entries, 0 to 50739
# Data columns (total 41 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Link                 50675 non-null  object
#  1   Listed               50675 non-null  object
#  2   Borough              50675 non-null  object
#  3   date_listed          50675 non-null  object
#  4   agency_name          50675 non-null  object
#  5   agency_phone         50628 non-null  object
#  6   chain_free           50675 non-null  object
#  7   address              50675 non-null  object
#  8   isRetirementHome     50675 non-null  object
#  9   isSharedOwnership    50675 non-null  object
#  10  listingCondition     50675 non-null  object
#  11  listingStatus        50675 non-null  object
#  12  RoomCount            50675 non-null  object
#  13  price                50675 non-null  float64
#  14  propertyType         48731 non-null  object
#  15  isAuction            50675 non-null  object
#  16  priceHistory         49244 non-null  object
#  17  floorArea            8224 non-null   object
#  18  tenure               32411 non-null  object
#  19  detailedDescription  50669 non-null  object
#  20  features             45195 non-null  object
#  21  furnishedState       953 non-null    object
#  22  title                50675 non-null  object
#  23  latitude             50675 non-null  float64
#  24  longitude            50675 non-null  float64
#  25  statusSummary        2015 non-null   object
#  26  floor_area_amount    8166 non-null   float64
#  27  floor_area_units     8224 non-null   object
#  28  floor_area_msq       8166 non-null   float64
#  29  numBedrooms          50675 non-null  int64
#  30  numBathrooms         50675 non-null  int64
#  31  numLivingRooms       50675 non-null  int64
#  32  firstPublished       49238 non-null  object
#  33  lastSale             21209 non-null  object
#  34  firstPublishedDate   49238 non-null  object
#  35  firstPublishedPrice  49238 non-null  float64
#  36  lastSaleDate         21209 non-null  object
#  37  lastSaleNewBuild     21209 non-null  object
#  38  lastSalePrice        21209 non-null  float64
#  39  sq_m_feat_from_ft    5650 non-null   float64
#  40  sq_m_feat_from_m     1603 non-null   float64
# dtypes: float64(9), int64(3), object(29)
# memory usage: 16.2+ MB

# %% [markdown]
# One the difficulties I am finding is to fill the floor size feature, even though I believe it is a feature of great importance there is very little houses with that information as it is. In fact, just around the 20% so far.
#
# I tried to extract this information from the features object by extracting any number related with sq ft or sq m, let's see how it improves the previous percentage.

# %%
df_houses_wrangling['floor_area_msq'] = df_houses_wrangling.apply(lambda x: x['sq_m_feat_from_ft'] 
                                                                     if np.isnan(x['floor_area_msq'])
                                                                    else x['floor_area_msq'], axis = 1)
df_houses_wrangling['floor_area_msq'] = df_houses_wrangling.apply(lambda x: x['sq_m_feat_from_m'] 
                                                                    if np.isnan(x['floor_area_msq'])
                                                                    else x['floor_area_msq'], axis = 1)

# %%
df_houses_wrangling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50675 entries, 0 to 50739
# Data columns (total 41 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Link                 50675 non-null  object
#  1   Listed               50675 non-null  object
#  2   Borough              50675 non-null  object
#  3   date_listed          50675 non-null  object
#  4   agency_name          50675 non-null  object
#  5   agency_phone         50628 non-null  object
#  6   chain_free           50675 non-null  object
#  7   address              50675 non-null  object
#  8   isRetirementHome     50675 non-null  object
#  9   isSharedOwnership    50675 non-null  object
#  10  listingCondition     50675 non-null  object
#  11  listingStatus        50675 non-null  object
#  12  RoomCount            50675 non-null  object
#  13  price                50675 non-null  float64
#  14  propertyType         48731 non-null  object
#  15  isAuction            50675 non-null  object
#  16  priceHistory         49244 non-null  object
#  17  floorArea            8224 non-null   object
#  18  tenure               32411 non-null  object
#  19  detailedDescription  50669 non-null  object
#  20  features             45195 non-null  object
#  21  furnishedState       953 non-null    object
#  22  title                50675 non-null  object
#  23  latitude             50675 non-null  float64
#  24  longitude            50675 non-null  float64
#  25  statusSummary        2015 non-null   object
#  26  floor_area_amount    8166 non-null   float64
#  27  floor_area_units     8224 non-null   object
#  28  floor_area_msq       12608 non-null  float64
#  29  numBedrooms          50675 non-null  int64
#  30  numBathrooms         50675 non-null  int64
#  31  numLivingRooms       50675 non-null  int64
#  32  firstPublished       49238 non-null  object
#  33  lastSale             21209 non-null  object
#  34  firstPublishedDate   49238 non-null  object
#  35  firstPublishedPrice  49238 non-null  float64
#  36  lastSaleDate         21209 non-null  object
#  37  lastSaleNewBuild     21209 non-null  object
#  38  lastSalePrice        21209 non-null  float64
#  39  sq_m_feat_from_ft    5650 non-null   float64
#  40  sq_m_feat_from_m     1603 non-null   float64
# dtypes: float64(9), int64(3), object(29)
# memory usage: 16.2+ MB

# %% [markdown]
# The situation has improved and now there is a better percentage (26%), even though still not great.
#
# Let's try now with the description, applying a similar method.

# %%
df_houses_wrangling['sq_m_feat_from_dft'] = df_houses_wrangling['detailedDescription'].apply(lambda x: None 
                                                                                             if pd.isnull(x) 
                                                                                    else sq_ft_features_find(x))

df_houses_wrangling['sq_m_feat_from_dm'] = df_houses_wrangling['detailedDescription'].apply(lambda x: None 
                                                                                            if pd.isnull(x) 
                                                                                     else sq_m_features_find(x))

# %%
df_houses_wrangling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50675 entries, 0 to 50739
# Data columns (total 43 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Link                 50675 non-null  object
#  1   Listed               50675 non-null  object
#  2   Borough              50675 non-null  object
#  3   date_listed          50675 non-null  object
#  4   agency_name          50675 non-null  object
#  5   agency_phone         50628 non-null  object
#  6   chain_free           50675 non-null  object
#  7   address              50675 non-null  object
#  8   isRetirementHome     50675 non-null  object
#  9   isSharedOwnership    50675 non-null  object
#  10  listingCondition     50675 non-null  object
#  11  listingStatus        50675 non-null  object
#  12  RoomCount            50675 non-null  object
#  13  price                50675 non-null  float64
#  14  propertyType         48731 non-null  object
#  15  isAuction            50675 non-null  object
#  16  priceHistory         49244 non-null  object
#  17  floorArea            8224 non-null   object
#  18  tenure               32411 non-null  object
#  19  detailedDescription  50669 non-null  object
#  20  features             45195 non-null  object
#  21  furnishedState       953 non-null    object
#  22  title                50675 non-null  object
#  23  latitude             50675 non-null  float64
#  24  longitude            50675 non-null  float64
#  25  statusSummary        2015 non-null   object
#  26  floor_area_amount    8166 non-null   float64
#  27  floor_area_units     8224 non-null   object
#  28  floor_area_msq       12608 non-null  float64
#  29  numBedrooms          50675 non-null  int64
#  30  numBathrooms         50675 non-null  int64
#  31  numLivingRooms       50675 non-null  int64
#  32  firstPublished       49238 non-null  object
#  33  lastSale             21209 non-null  object
#  34  firstPublishedDate   49238 non-null  object
#  35  firstPublishedPrice  49238 non-null  float64
#  36  lastSaleDate         21209 non-null  object
#  37  lastSaleNewBuild     21209 non-null  object
#  38  lastSalePrice        21209 non-null  float64
#  39  sq_m_feat_from_ft    5650 non-null   float64
#  40  sq_m_feat_from_m     1603 non-null   float64
#  41  sq_m_feat_from_dft   10501 non-null  float64
#  42  sq_m_feat_from_dm    1911 non-null   float64
# dtypes: float64(11), int64(3), object(29)
# memory usage: 17.0+ MB

# %%
df_houses_wrangling['floor_area_msq'] = df_houses_wrangling.apply(lambda x: x['sq_m_feat_from_dft'] 
                                                                     if np.isnan(x['floor_area_msq'])
                                                                    else x['floor_area_msq'], axis = 1)
df_houses_wrangling['floor_area_msq'] = df_houses_wrangling.apply(lambda x: x['sq_m_feat_from_dm'] 
                                                                    if np.isnan(x['floor_area_msq'])
                                                                    else x['floor_area_msq'], axis = 1)

# %%
df_houses_wrangling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50675 entries, 0 to 50739
# Data columns (total 43 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Link                 50675 non-null  object
#  1   Listed               50675 non-null  object
#  2   Borough              50675 non-null  object
#  3   date_listed          50675 non-null  object
#  4   agency_name          50675 non-null  object
#  5   agency_phone         50628 non-null  object
#  6   chain_free           50675 non-null  object
#  7   address              50675 non-null  object
#  8   isRetirementHome     50675 non-null  object
#  9   isSharedOwnership    50675 non-null  object
#  10  listingCondition     50675 non-null  object
#  11  listingStatus        50675 non-null  object
#  12  RoomCount            50675 non-null  object
#  13  price                50675 non-null  float64
#  14  propertyType         48731 non-null  object
#  15  isAuction            50675 non-null  object
#  16  priceHistory         49244 non-null  object
#  17  floorArea            8224 non-null   object
#  18  tenure               32411 non-null  object
#  19  detailedDescription  50669 non-null  object
#  20  features             45195 non-null  object
#  21  furnishedState       953 non-null    object
#  22  title                50675 non-null  object
#  23  latitude             50675 non-null  float64
#  24  longitude            50675 non-null  float64
#  25  statusSummary        2015 non-null   object
#  26  floor_area_amount    8166 non-null   float64
#  27  floor_area_units     8224 non-null   object
#  28  floor_area_msq       18443 non-null  float64
#  29  numBedrooms          50675 non-null  int64
#  30  numBathrooms         50675 non-null  int64
#  31  numLivingRooms       50675 non-null  int64
#  32  firstPublished       49238 non-null  object
#  33  lastSale             21209 non-null  object
#  34  firstPublishedDate   49238 non-null  object
#  35  firstPublishedPrice  49238 non-null  float64
#  36  lastSaleDate         21209 non-null  object
#  37  lastSaleNewBuild     21209 non-null  object
#  38  lastSalePrice        21209 non-null  float64
#  39  sq_m_feat_from_ft    5650 non-null   float64
#  40  sq_m_feat_from_m     1603 non-null   float64
#  41  sq_m_feat_from_dft   10501 non-null  float64
#  42  sq_m_feat_from_dm    1911 non-null   float64
# dtypes: float64(11), int64(3), object(29)
# memory usage: 17.0+ MB

# %% [markdown]
# Using the description feature, the situation improves to almost 40%, but I don't think it is possible to improve further. If that is the case, I will drop the rows without floor area information.
#
# In that case I will drop the null values rows. Between 15k and 20k is a good sample of houses to make a reliable study,

# %%
df_houses_wrangling2 = df_houses_wrangling.copy()

# %%
df_houses_wrangling2.columns
# Out:
# Index(['Link', 'Listed', 'Borough', 'date_listed', 'agency_name',
#        'agency_phone', 'chain_free', 'address', 'isRetirementHome',
#        'isSharedOwnership', 'listingCondition', 'listingStatus', 'RoomCount',
#        'price', 'propertyType', 'isAuction', 'priceHistory', 'floorArea',
#        'tenure', 'detailedDescription', 'features', 'furnishedState', 'title',
#        'latitude', 'longitude', 'statusSummary', 'floor_area_amount',
#        'floor_area_units', 'floor_area_msq', 'numBedrooms', 'numBathrooms',
#        'numLivingRooms', 'firstPublished', 'lastSale', 'firstPublishedDate',
#        'firstPublishedPrice', 'lastSaleDate', 'lastSaleNewBuild',
#        'lastSalePrice', 'sq_m_feat_from_ft', 'sq_m_feat_from_m',
#        'sq_m_feat_from_dft', 'sq_m_feat_from_dm'],
#       dtype='object')

# %%
df_houses_wrangling2 = df_houses_wrangling2.drop(['Link','Listed','agency_phone','RoomCount','priceHistory',
                                                 'floorArea','floor_area_amount','floor_area_units',
                                                  'firstPublished','lastSale','sq_m_feat_from_ft',
                                                  'sq_m_feat_from_m','sq_m_feat_from_dft','sq_m_feat_from_dm'],
                                                axis = 1)
df_houses_wrangling2 = df_houses_wrangling2[df_houses_wrangling2['floor_area_msq'].notnull()].reset_index(drop = True)
df_houses_wrangling2
# Out:
#               Borough date_listed                     agency_name chain_free  \
# 0              Camden  2021-06-30   Savills - Margaret Street RDS       True
# 1              Camden  2021-06-30                TK International      False
# 2              Camden  2021-06-30  Knight Frank - Hampstead Sales      False
# 3              Camden  2021-06-30       Barnard Marcus - Auctions      False
# 4              Camden  2021-06-30                Amberden Estates      False
# ...               ...         ...                             ...        ...
# 18438  Waltham Forest  2021-02-01    Linus Jackson Property Agent       True
# 18439  Waltham Forest  2021-02-01                 Quatremain & Co      False
# 18440  Waltham Forest  2021-01-28               The Stow Brothers      False
# 18441  Waltham Forest  2021-01-28            The Stow Brothers E4      False
# 18442  Waltham Forest  2021-01-27          Trevlyn Properties Ltd      False
#
#                                       address isRetirementHome  \
# 0       Postmark, Mount Pleasant, London WC1X            False
# 1      Holly Bush Vale, Hampstead Village NW3            False
# 2                    Frognal Lane, London NW3            False
# 3                   Cosway Street, London NW1            False
# 4                 Parliament Hill, London NW3            False
# ...                                       ...              ...
# 18438                 Church Road, London E10            False
# 18439  Walnut Court, Woodmill Road, London E5            False
# 18440               Belgrave Road, London E11            False
# 18441               Parade Gardens, London E4            False
# 18442        Blackhorse Road, Walthamstow E17            False
#
#       isSharedOwnership listingCondition listingStatus      price  ...  \
# 0                 False              new      for_sale  1330000.0  ...
# 1                 False        pre-owned      for_sale   695000.0  ...
# 2                 False        pre-owned      for_sale   595000.0  ...
# 3                 False        pre-owned      for_sale  1750000.0  ...
# 4                 False        pre-owned      for_sale  4995000.0  ...
# ...                 ...              ...           ...        ...  ...
# 18438             False        pre-owned      for_sale   335000.0  ...
# 18439             False        pre-owned      for_sale   300000.0  ...
# 18440             False        pre-owned      for_sale   342995.0  ...
# 18441             False        pre-owned      for_sale   395000.0  ...
# 18442             False        pre-owned      for_sale   409999.0  ...
#
#       statusSummary floor_area_msq numBedrooms numBathrooms numLivingRooms  \
# 0        Just added           85.0           2            2              1
# 1        Just added           47.0           1            1              1
# 2        Just added           49.0           1            1              1
# 3        Just added          234.0           7            7              0
# 4        Just added          321.0           7            2              0
# ...             ...            ...         ...          ...            ...
# 18438           NaN           58.0           2            1              1
# 18439           NaN           46.0           2            1              1
# 18440           NaN           15.0           2            1              1
# 18441           NaN           26.0           2            1              1
# 18442           NaN           58.0           1            1              1
#
#         firstPublishedDate firstPublishedPrice  lastSaleDate  \
# 0      2021-06-30 23:07:17           1330000.0          None
# 1      2021-06-30 18:06:20            695000.0    2018-02-21
# 2      2021-06-30 16:29:58            595000.0          None
# 3      2021-06-30 16:28:37           1750000.0          None
# 4      2021-06-30 16:04:51           4995000.0          None
# ...                    ...                 ...           ...
# 18438  2021-02-01 16:49:35            350000.0          None
# 18439  2021-02-01 14:08:26            350000.0    2007-12-06
# 18440  2021-01-28 15:16:47            349995.0    2011-03-18
# 18441  2021-01-28 09:46:03            395000.0          None
# 18442  2021-01-27 14:18:51            409999.0          None
#
#        lastSaleNewBuild lastSalePrice
# 0                  None           NaN
# 1                 False      465000.0
# 2                  None           NaN
# 3                  None           NaN
# 4                  None           NaN
# ...                 ...           ...
# 18438              None           NaN
# 18439             False      240000.0
# 18440             False      152000.0
# 18441              None           NaN
# 18442              None           NaN
#
# [18443 rows x 29 columns]

# %%
df_houses_wrangling2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18443 entries, 0 to 18442
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Borough              18443 non-null  object
#  1   date_listed          18443 non-null  object
#  2   agency_name          18443 non-null  object
#  3   chain_free           18443 non-null  object
#  4   address              18443 non-null  object
#  5   isRetirementHome     18443 non-null  object
#  6   isSharedOwnership    18443 non-null  object
#  7   listingCondition     18443 non-null  object
#  8   listingStatus        18443 non-null  object
#  9   price                18443 non-null  float64
#  10  propertyType         17848 non-null  object
#  11  isAuction            18443 non-null  object
#  12  tenure               11915 non-null  object
#  13  detailedDescription  18443 non-null  object
#  14  features             17085 non-null  object
#  15  furnishedState       788 non-null    object
#  16  title                18443 non-null  object
#  17  latitude             18443 non-null  float64
#  18  longitude            18443 non-null  float64
#  19  statusSummary        699 non-null    object
#  20  floor_area_msq       18443 non-null  float64
#  21  numBedrooms          18443 non-null  int64
#  22  numBathrooms         18443 non-null  int64
#  23  numLivingRooms       18443 non-null  int64
#  24  firstPublishedDate   17872 non-null  object
#  25  firstPublishedPrice  17872 non-null  float64
#  26  lastSaleDate         6522 non-null   object
#  27  lastSaleNewBuild     6522 non-null   object
#  28  lastSalePrice        6522 non-null   float64
# dtypes: float64(6), int64(3), object(20)
# memory usage: 4.1+ MB

# %% [markdown]
# I will get rid of furnished state and status summary as they do not give much information and almost all records are missing.

# %%
df_houses_wrangling2 = df_houses_wrangling2.drop(['furnishedState','statusSummary'],
                                                axis = 1)

# %%
df_houses_wrangling2['listingStatus'].value_counts()
# Out:
# for_sale            18431
# sold                    6
# sale_under_offer        6
# Name: listingStatus, dtype: int64

# %% [markdown]
# Listing status feature also gives very little information and completely useless for the purpose of the study.

# %%
df_houses_wrangling2 = df_houses_wrangling2.drop(['listingStatus'],
                                                axis = 1)

# %%
df_houses_wrangling2['propertyType'].value_counts()
# Out:
# flat                      13089
# terraced                   1471
# semi_detached               919
# detached                    682
# maisonette                  569
# studio                      479
# end_terrace                 300
# town_house                  107
# mews                         52
# land                         36
# bungalow                     29
# block_of_flats               25
# detached_bungalow            20
# cottage                      16
# link_detached                10
# houseboat                    10
# semi_detached_bungalow        9
# parking                       8
# lodge                         5
# retail                        5
# barn_conversion               3
# country_house                 1
# chalet                        1
# finca                         1
# villa                         1
# Name: propertyType, dtype: int64

# %% [markdown]
# I will complete the missing values of property type seting them as "Other".
#
# In the future I will have to deal with the fact that there are many different categorical options.

# %%
df_houses_wrangling2['propertyType'].fillna(value = 'Other', inplace = True)

# %%
df_houses_wrangling2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18443 entries, 0 to 18442
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Borough              18443 non-null  object
#  1   date_listed          18443 non-null  object
#  2   agency_name          18443 non-null  object
#  3   chain_free           18443 non-null  object
#  4   address              18443 non-null  object
#  5   isRetirementHome     18443 non-null  object
#  6   isSharedOwnership    18443 non-null  object
#  7   listingCondition     18443 non-null  object
#  8   price                18443 non-null  float64
#  9   propertyType         18443 non-null  object
#  10  isAuction            18443 non-null  object
#  11  tenure               11915 non-null  object
#  12  detailedDescription  18443 non-null  object
#  13  features             17085 non-null  object
#  14  title                18443 non-null  object
#  15  latitude             18443 non-null  float64
#  16  longitude            18443 non-null  float64
#  17  floor_area_msq       18443 non-null  float64
#  18  numBedrooms          18443 non-null  int64
#  19  numBathrooms         18443 non-null  int64
#  20  numLivingRooms       18443 non-null  int64
#  21  firstPublishedDate   17872 non-null  object
#  22  firstPublishedPrice  17872 non-null  float64
#  23  lastSaleDate         6522 non-null   object
#  24  lastSaleNewBuild     6522 non-null   object
#  25  lastSalePrice        6522 non-null   float64
# dtypes: float64(6), int64(3), object(17)
# memory usage: 3.7+ MB

# %%
df_houses_wrangling2['tenure'].value_counts()
# Out:
# leasehold            7873
# freehold             2627
# share_of_freehold    1412
# feudal                  3
# Name: tenure, dtype: int64

# %% [markdown]
# I will try now to complete tenure feature missing values using features and description features. This time will be more simple as we just need to find a mention to any of the 4 options.

# %%
patterns = [r'(leasehold)',
            r'(lease)',
            r'(freehold)',
            r'(share.of.freehold)',
            r'(feudal)',
            r'(leaseholder)',
            r'(freeholder)',
            r'(commonhold)']

df_houses_wrangling2['tenure_from_feat'] = df_houses_wrangling2['features'].apply(lambda x: None if pd.isnull(x) 
                                                                                else extract_feature(x,patterns))
df_houses_wrangling2['tenure_from_desc'] = df_houses_wrangling2['detailedDescription'].apply(lambda x: None 
                                                                                             if pd.isnull(x) 
                                                                                else extract_feature(x,patterns))
df_houses_wrangling2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18443 entries, 0 to 18442
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Borough              18443 non-null  object
#  1   date_listed          18443 non-null  object
#  2   agency_name          18443 non-null  object
#  3   chain_free           18443 non-null  object
#  4   address              18443 non-null  object
#  5   isRetirementHome     18443 non-null  object
#  6   isSharedOwnership    18443 non-null  object
#  7   listingCondition     18443 non-null  object
#  8   price                18443 non-null  float64
#  9   propertyType         18443 non-null  object
#  10  isAuction            18443 non-null  object
#  11  tenure               11915 non-null  object
#  12  detailedDescription  18443 non-null  object
#  13  features             17085 non-null  object
#  14  title                18443 non-null  object
#  15  latitude             18443 non-null  float64
#  16  longitude            18443 non-null  float64
#  17  floor_area_msq       18443 non-null  float64
#  18  numBedrooms          18443 non-null  int64
#  19  numBathrooms         18443 non-null  int64
#  20  numLivingRooms       18443 non-null  int64
#  21  firstPublishedDate   17872 non-null  object
#  22  firstPublishedPrice  17872 non-null  float64
#  23  lastSaleDate         6522 non-null   object
#  24  lastSaleNewBuild     6522 non-null   object
#  25  lastSalePrice        6522 non-null   float64
#  26  tenure_from_feat     1313 non-null   object
#  27  tenure_from_desc     5419 non-null   object
# dtypes: float64(6), int64(3), object(19)
# memory usage: 3.9+ MB

# %%
df_houses_wrangling2['tenure'] = df_houses_wrangling2.apply(lambda x: x['tenure_from_feat'] 
                                                                     if pd.isnull(x['tenure'])
                                                                    else x['tenure'], axis = 1)
df_houses_wrangling2['tenure'] = df_houses_wrangling2.apply(lambda x: x['tenure_from_desc'] 
                                                                     if pd.isnull(x['tenure'])
                                                                    else x['tenure'], axis = 1)
df_houses_wrangling2['tenure'].value_counts()
# Out:
# leasehold            7943
# freehold             2976
# lease                1583
# share_of_freehold    1412
# feudal                  3
# Name: tenure, dtype: int64

# %%
tenure_map = {'lease':'leasehold','feudal':'Other'}
df_houses_wrangling2['tenure'].replace(tenure_map, inplace = True)
df_houses_wrangling2['tenure'] = df_houses_wrangling2['tenure'].fillna('Other')
df_houses_wrangling2['tenure'].value_counts()
# Out:
# leasehold            9526
# Other                4529
# freehold             2976
# share_of_freehold    1412
# Name: tenure, dtype: int64

# %%
df_houses_wrangling2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18443 entries, 0 to 18442
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Borough              18443 non-null  object
#  1   date_listed          18443 non-null  object
#  2   agency_name          18443 non-null  object
#  3   chain_free           18443 non-null  object
#  4   address              18443 non-null  object
#  5   isRetirementHome     18443 non-null  object
#  6   isSharedOwnership    18443 non-null  object
#  7   listingCondition     18443 non-null  object
#  8   price                18443 non-null  float64
#  9   propertyType         18443 non-null  object
#  10  isAuction            18443 non-null  object
#  11  tenure               18443 non-null  object
#  12  detailedDescription  18443 non-null  object
#  13  features             17085 non-null  object
#  14  title                18443 non-null  object
#  15  latitude             18443 non-null  float64
#  16  longitude            18443 non-null  float64
#  17  floor_area_msq       18443 non-null  float64
#  18  numBedrooms          18443 non-null  int64
#  19  numBathrooms         18443 non-null  int64
#  20  numLivingRooms       18443 non-null  int64
#  21  firstPublishedDate   17872 non-null  object
#  22  firstPublishedPrice  17872 non-null  float64
#  23  lastSaleDate         6522 non-null   object
#  24  lastSaleNewBuild     6522 non-null   object
#  25  lastSalePrice        6522 non-null   float64
#  26  tenure_from_feat     1313 non-null   object
#  27  tenure_from_desc     5419 non-null   object
# dtypes: float64(6), int64(3), object(19)
# memory usage: 3.9+ MB

# %%
patterns = [r'(terrace)',
            r'(balcony)',
            r'(roof.deck)']

df_houses_wrangling2['balcony_terrace'] = df_houses_wrangling2['features'].apply(lambda x: False if pd.isnull(x) 
                                                            else (True if pd.notnull(extract_feature(x,patterns)) 
                                                            else False))
df_houses_wrangling2['balcony_terrace'] = df_houses_wrangling2.apply(lambda x: False 
                                                if pd.isnull(x['detailedDescription']) 
                                                else (True if x['balcony_terrace'] == True 
                                                else (True 
                                                if pd.notnull(extract_feature(x['detailedDescription'],patterns)) 
                                                else False)), 
                                                axis = 1)
df_houses_wrangling2['balcony_terrace'].value_counts()
# Out:
# False    9901
# True     8542
# Name: balcony_terrace, dtype: int64

# %%
patterns = [r'(car.park)',
            r'(carpark)',
            r'(parking)']

df_houses_wrangling2['parking'] = df_houses_wrangling2['features'].apply(lambda x: False if pd.isnull(x) 
                                                            else (True if pd.notnull(extract_feature(x,patterns)) 
                                                            else False))
df_houses_wrangling2['parking'] = df_houses_wrangling2.apply(lambda x: False 
                                                if pd.isnull(x['detailedDescription']) 
                                                else (True if x['parking'] == True 
                                                else (True 
                                                if pd.notnull(extract_feature(x['detailedDescription'],patterns)) 
                                                else False)), 
                                                axis = 1)
df_houses_wrangling2['parking'].value_counts()
# Out:
# False    12404
# True      6039
# Name: parking, dtype: int64

# %%
patterns = [r'(garden)',
            r'(backyard)',
           r'(back.yard)',
           r'(patio)']

df_houses_wrangling2['garden'] = df_houses_wrangling2['features'].apply(lambda x: False if pd.isnull(x) 
                                                            else (True if pd.notnull(extract_feature(x,patterns)) 
                                                            else False))
df_houses_wrangling2['garden'] = df_houses_wrangling2.apply(lambda x: False 
                                                if pd.isnull(x['detailedDescription']) 
                                                else (True if x['garden'] == True 
                                                else (True 
                                                if pd.notnull(extract_feature(x['detailedDescription'],patterns)) 
                                                else False)), 
                                                axis = 1)
df_houses_wrangling2['garden'].value_counts()
# Out:
# True     10196
# False     8247
# Name: garden, dtype: int64

# %%
df_houses_wrangling2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18443 entries, 0 to 18442
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Borough              18443 non-null  object
#  1   date_listed          18443 non-null  object
#  2   agency_name          18443 non-null  object
#  3   chain_free           18443 non-null  object
#  4   address              18443 non-null  object
#  5   isRetirementHome     18443 non-null  object
#  6   isSharedOwnership    18443 non-null  object
#  7   listingCondition     18443 non-null  object
#  8   price                18443 non-null  float64
#  9   propertyType         18443 non-null  object
#  10  isAuction            18443 non-null  object
#  11  tenure               18443 non-null  object
#  12  detailedDescription  18443 non-null  object
#  13  features             17085 non-null  object
#  14  title                18443 non-null  object
#  15  latitude             18443 non-null  float64
#  16  longitude            18443 non-null  float64
#  17  floor_area_msq       18443 non-null  float64
#  18  numBedrooms          18443 non-null  int64
#  19  numBathrooms         18443 non-null  int64
#  20  numLivingRooms       18443 non-null  int64
#  21  firstPublishedDate   17872 non-null  object
#  22  firstPublishedPrice  17872 non-null  float64
#  23  lastSaleDate         6522 non-null   object
#  24  lastSaleNewBuild     6522 non-null   object
#  25  lastSalePrice        6522 non-null   float64
#  26  tenure_from_feat     1313 non-null   object
#  27  tenure_from_desc     5419 non-null   object
#  28  balcony_terrace      18443 non-null  bool
#  29  parking              18443 non-null  bool
#  30  garden               18443 non-null  bool
# dtypes: bool(3), float64(6), int64(3), object(19)
# memory usage: 4.0+ MB

# %% [markdown]
# First published date shows a small amount of missing values. I will fill them using its value in date_listed, basically asuming that the house is the first time published. I will do the same for price.
#
# First I need to convert the feature in datetime of the same format as date_listed.

# %%
df_houses_wrangling2['firstPublishedDate'] = df_houses_wrangling2['firstPublishedDate'].apply(lambda x: None 
                                                                                              if pd.isnull(x)
                                                                                             else x.split(' ')[0])
df_houses_wrangling2['firstPublishedDate']
# Out:
# 0        2021-06-30
# 1        2021-06-30
# 2        2021-06-30
# 3        2021-06-30
# 4        2021-06-30
#             ...
# 18438    2021-02-01
# 18439    2021-02-01
# 18440    2021-01-28
# 18441    2021-01-28
# 18442    2021-01-27
# Name: firstPublishedDate, Length: 18443, dtype: object

# %%
df_houses_wrangling2['firstPublishedDate'] = df_houses_wrangling2['firstPublishedDate'].fillna(df_houses_wrangling2['date_listed'])

# %%
df_houses_wrangling2['firstPublishedPrice'] = df_houses_wrangling2['firstPublishedPrice'].fillna(df_houses_wrangling2['price'])

# %%
df_houses_wrangling2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18443 entries, 0 to 18442
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Borough              18443 non-null  object
#  1   date_listed          18443 non-null  object
#  2   agency_name          18443 non-null  object
#  3   chain_free           18443 non-null  object
#  4   address              18443 non-null  object
#  5   isRetirementHome     18443 non-null  object
#  6   isSharedOwnership    18443 non-null  object
#  7   listingCondition     18443 non-null  object
#  8   price                18443 non-null  float64
#  9   propertyType         18443 non-null  object
#  10  isAuction            18443 non-null  object
#  11  tenure               18443 non-null  object
#  12  detailedDescription  18443 non-null  object
#  13  features             17085 non-null  object
#  14  title                18443 non-null  object
#  15  latitude             18443 non-null  float64
#  16  longitude            18443 non-null  float64
#  17  floor_area_msq       18443 non-null  float64
#  18  numBedrooms          18443 non-null  int64
#  19  numBathrooms         18443 non-null  int64
#  20  numLivingRooms       18443 non-null  int64
#  21  firstPublishedDate   18443 non-null  object
#  22  firstPublishedPrice  18443 non-null  float64
#  23  lastSaleDate         6522 non-null   object
#  24  lastSaleNewBuild     6522 non-null   object
#  25  lastSalePrice        6522 non-null   float64
#  26  tenure_from_feat     1313 non-null   object
#  27  tenure_from_desc     5419 non-null   object
#  28  balcony_terrace      18443 non-null  bool
#  29  parking              18443 non-null  bool
#  30  garden               18443 non-null  bool
# dtypes: bool(3), float64(6), int64(3), object(19)
# memory usage: 4.0+ MB

# %% [markdown]
# Now I will drop the used features and also last sale, as it shows too many missing values and also it provides very little information.

# %%
df_houses_wrangling2.drop(['detailedDescription','features','lastSaleDate','lastSaleNewBuild',
                           'lastSalePrice','tenure_from_feat','tenure_from_desc'],
                         inplace = True,
                         axis = 1)
df_houses_wrangling2
# Out:
#               Borough date_listed                     agency_name chain_free  \
# 0              Camden  2021-06-30   Savills - Margaret Street RDS       True
# 1              Camden  2021-06-30                TK International      False
# 2              Camden  2021-06-30  Knight Frank - Hampstead Sales      False
# 3              Camden  2021-06-30       Barnard Marcus - Auctions      False
# 4              Camden  2021-06-30                Amberden Estates      False
# ...               ...         ...                             ...        ...
# 18438  Waltham Forest  2021-02-01    Linus Jackson Property Agent       True
# 18439  Waltham Forest  2021-02-01                 Quatremain & Co      False
# 18440  Waltham Forest  2021-01-28               The Stow Brothers      False
# 18441  Waltham Forest  2021-01-28            The Stow Brothers E4      False
# 18442  Waltham Forest  2021-01-27          Trevlyn Properties Ltd      False
#
#                                       address isRetirementHome  \
# 0       Postmark, Mount Pleasant, London WC1X            False
# 1      Holly Bush Vale, Hampstead Village NW3            False
# 2                    Frognal Lane, London NW3            False
# 3                   Cosway Street, London NW1            False
# 4                 Parliament Hill, London NW3            False
# ...                                       ...              ...
# 18438                 Church Road, London E10            False
# 18439  Walnut Court, Woodmill Road, London E5            False
# 18440               Belgrave Road, London E11            False
# 18441               Parade Gardens, London E4            False
# 18442        Blackhorse Road, Walthamstow E17            False
#
#       isSharedOwnership listingCondition      price    propertyType  ...  \
# 0                 False              new  1330000.0            flat  ...
# 1                 False        pre-owned   695000.0            flat  ...
# 2                 False        pre-owned   595000.0            flat  ...
# 3                 False        pre-owned  1750000.0  block_of_flats  ...
# 4                 False        pre-owned  4995000.0   semi_detached  ...
# ...                 ...              ...        ...             ...  ...
# 18438             False        pre-owned   335000.0            flat  ...
# 18439             False        pre-owned   300000.0            flat  ...
# 18440             False        pre-owned   342995.0            flat  ...
# 18441             False        pre-owned   395000.0            flat  ...
# 18442             False        pre-owned   409999.0            flat  ...
#
#       longitude floor_area_msq numBedrooms  numBathrooms  numLivingRooms  \
# 0     -0.112205           85.0           2             2               1
# 1     -0.179551           47.0           1             1               1
# 2     -0.187055           49.0           1             1               1
# 3     -0.165689          234.0           7             7               0
# 4     -0.162663          321.0           7             2               0
# ...         ...            ...         ...           ...             ...
# 18438 -0.016124           58.0           2             1               1
# 18439 -0.050792           46.0           2             1               1
# 18440  0.023347           15.0           2             1               1
# 18441 -0.015026           26.0           2             1               1
# 18442 -0.041873           58.0           1             1               1
#
#        firstPublishedDate  firstPublishedPrice  balcony_terrace  parking  \
# 0              2021-06-30            1330000.0             True    False
# 1              2021-06-30             695000.0            False     True
# 2              2021-06-30             595000.0            False    False
# 3              2021-06-30            1750000.0            False    False
# 4              2021-06-30            4995000.0             True    False
# ...                   ...                  ...              ...      ...
# 18438          2021-02-01             350000.0            False    False
# 18439          2021-02-01             350000.0            False    False
# 18440          2021-01-28             349995.0            False     True
# 18441          2021-01-28             395000.0             True     True
# 18442          2021-01-27             409999.0             True    False
#
#       garden
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
# ...      ...
# 18438  False
# 18439  False
# 18440   True
# 18441   True
# 18442   True
#
# [18443 rows x 24 columns]

# %%
engine = create_engine('mysql+mysqldb://root:d12d12@127.0.0.1/zoopla_houses', echo=False)

# %%
df_houses_wrangling2.to_sql('zoopla_houses', con=engine)
