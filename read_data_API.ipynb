# %%
import requests
from bs4 import BeautifulSoup as soup
import numpy as np
import pandas as pd
import math

# %%
# Function to get the number of pages of an specific borough
def number_of_search_pages(url):
    page = requests.get(url)
    if page.status_code != 200:
        print('Url provided not valid')
    else:
        bsobj = soup(page.content, 'html5lib')
        pages_html = bsobj.find('p',{'data-testid':'total-results'})
        pages = pages_html.get_text().split()
        house_num = int(pages[0])
        pages = math.ceil(int(pages[0])/25)
        return pd.Series((pages, house_num))

# %%
# Function to build the url for each borough
def get_borough_url(borough):
    boruough_split = borough.split()
    if len(boruough_split) == 1:
        url = 'https://www.zoopla.co.uk/for-sale/property/' + borough + '-london-borough/?page_size=25&q=' \
        + borough.lower() + '&radius=0&results_sort=newest_listings&pn=1'
    else:
        for i in range(0,len(boruough_split)):
            if i == 0:
                item_1 = boruough_split[i]
                item_2 = boruough_split[i].lower()
            else:
                item_1 = item_1 + '-' + boruough_split[i]
                item_2 = item_2 + '%20' + boruough_split[i].lower()
        url = 'https://www.zoopla.co.uk/for-sale/property/' + item_1 + '-london-borough/?page_size=25&q=' \
        + item_2 + '&radius=0&results_sort=newest_listings&pn=1'
    return url

# %%
# Function to scrape links and other details from main search page of each house
def get_main_house_details(url_initial, pages, house_num):
    url_initial = url_initial[:-1]
    link = []
    price = []
    listed = []
    for i in range(1,pages+1):
        url = url_initial + str(i)
        page = requests.get(url)
        bsobj = soup(page.content, 'html5lib')
        for j in bsobj.findAll('a',{'data-testid':'listing-details-link'}, href=True):
            link.append(j.get('href'))
        for j in bsobj.findAll('div',{'class':'css-1e28vvi-PriceContainer e2uk8e8'}):
            price.append(j.find('p',{'class':'css-6v9gpl-Text eczcs4p0'}).text)
        for j in bsobj.findAll('span',{'data-testid':'date-published'}):
            listed.append(j.text)
    return link, price, listed

# %%
# List of London Boroughs
london_borough = ['Camden','Greenwich','Hackney','Hammersmith','Islington','Kensington and Chelsea',
                 'Lambeth','Lewisham','Southwark','Tower Hamlets','Wandsworth','Westminster','Barking',
                 'Barnet','Bexley','Brent','Bromley','Croydon','Ealing','Enfield','Haringey','Harrow',
                 'Havering','Hillingdon','Hounslow','Kingston upon Thames','Merton','Newham','Redbridge',
                 'Richmond upon Thames','Sutton','Waltham Forest']

# %%
df_boroughs = pd.DataFrame(london_borough)
df_boroughs.columns = ['borough_name']
df_boroughs['borough_url'] = df_boroughs['borough_name'].apply(lambda x: get_borough_url(x))
df_boroughs[['pages','house_num']] = df_boroughs['borough_url'].apply(lambda x: number_of_search_pages(x))
df_boroughs
# Out:
#               borough_name                                        borough_url  \
# 0                   Camden  https://www.zoopla.co.uk/for-sale/property/Cam...
# 1                Greenwich  https://www.zoopla.co.uk/for-sale/property/Gre...
# 2                  Hackney  https://www.zoopla.co.uk/for-sale/property/Hac...
# 3              Hammersmith  https://www.zoopla.co.uk/for-sale/property/Ham...
# 4                Islington  https://www.zoopla.co.uk/for-sale/property/Isl...
# 5   Kensington and Chelsea  https://www.zoopla.co.uk/for-sale/property/Ken...
# 6                  Lambeth  https://www.zoopla.co.uk/for-sale/property/Lam...
# 7                 Lewisham  https://www.zoopla.co.uk/for-sale/property/Lew...
# 8                Southwark  https://www.zoopla.co.uk/for-sale/property/Sou...
# 9            Tower Hamlets  https://www.zoopla.co.uk/for-sale/property/Tow...
# 10              Wandsworth  https://www.zoopla.co.uk/for-sale/property/Wan...
# 11             Westminster  https://www.zoopla.co.uk/for-sale/property/Wes...
# 12                 Barking  https://www.zoopla.co.uk/for-sale/property/Bar...
# 13                  Barnet  https://www.zoopla.co.uk/for-sale/property/Bar...
# 14                  Bexley  https://www.zoopla.co.uk/for-sale/property/Bex...
# 15                   Brent  https://www.zoopla.co.uk/for-sale/property/Bre...
# 16                 Bromley  https://www.zoopla.co.uk/for-sale/property/Bro...
# 17                 Croydon  https://www.zoopla.co.uk/for-sale/property/Cro...
# 18                  Ealing  https://www.zoopla.co.uk/for-sale/property/Eal...
# 19                 Enfield  https://www.zoopla.co.uk/for-sale/property/Enf...
# 20                Haringey  https://www.zoopla.co.uk/for-sale/property/Har...
# 21                  Harrow  https://www.zoopla.co.uk/for-sale/property/Har...
# 22                Havering  https://www.zoopla.co.uk/for-sale/property/Hav...
# 23              Hillingdon  https://www.zoopla.co.uk/for-sale/property/Hil...
# 24                Hounslow  https://www.zoopla.co.uk/for-sale/property/Hou...
# 25    Kingston upon Thames  https://www.zoopla.co.uk/for-sale/property/Kin...
# 26                  Merton  https://www.zoopla.co.uk/for-sale/property/Mer...
# 27                  Newham  https://www.zoopla.co.uk/for-sale/property/New...
# 28               Redbridge  https://www.zoopla.co.uk/for-sale/property/Red...
# 29    Richmond upon Thames  https://www.zoopla.co.uk/for-sale/property/Ric...
# 30                  Sutton  https://www.zoopla.co.uk/for-sale/property/Sut...
# 31          Waltham Forest  https://www.zoopla.co.uk/for-sale/property/Wal...
#
#     pages  house_num
# 0     115       2869
# 1      23        574
# 2      77       1921
# 3      40        978
# 4     106       2631
# 5     157       3915
# 6     137       3408
# 7      81       2015
# 8     105       2613
# 9     167       4171
# 10    181       4501
# 11    229       5703
# 12     10        248
# 13    142       3545
# 14     27        662
# 15    125       3121
# 16     55       1367
# 17    106       2646
# 18    124       3097
# 19     53       1306
# 20     56       1392
# 21     62       1536
# 22     38        943
# 23     71       1753
# 24     78       1941
# 25     22        540
# 26     59       1472
# 27     72       1784
# 28     47       1159
# 29     76       1882
# 30     32        778
# 31     41       1014

# %%
Camden_links, Camden_price, Camdem_listed = get_main_house_details(df_boroughs['borough_url'][0],df_boroughs['pages'][0],df_boroughs['house_num'][0])

# %%
Camden = pd.DataFrame({'Link':Camden_links,'Price':Camden_price,'Listed':Camdem_listed},
                     columns = ['Link','Price','Listed'])
Camden['Brough'] = 'Camden'
Camden
# Out:
#                               Link       Price                   Listed  \
# 0      /for-sale/details/55756717/    £445,000  Listed on 21st Jun 2021
# 1      /for-sale/details/58963984/    £525,000  Listed on 21st Jun 2021
# 2      /for-sale/details/58963688/  £1,275,000  Listed on 21st Jun 2021
# 3      /for-sale/details/58963510/    £555,000  Listed on 21st Jun 2021
# 4      /for-sale/details/58962200/    £555,000  Listed on 21st Jun 2021
# ...                            ...         ...                      ...
# 2864   /for-sale/details/40915563/  £1,095,000   Listed on 3rd Jul 2016
# 2865  /new-homes/details/36669950/  £1,500,000  Listed on 27th May 2016
# 2866   /for-sale/details/55400494/    £950,000  Listed on 24th May 2016
# 2867   /for-sale/details/39748209/    £731,000   Listed on 9th Mar 2016
# 2868   /for-sale/details/34954352/  £1,250,000  Listed on 24th Oct 2014
#
#       Brough
# 0     Camden
# 1     Camden
# 2     Camden
# 3     Camden
# 4     Camden
# ...      ...
# 2864  Camden
# 2865  Camden
# 2866  Camden
# 2867  Camden
# 2868  Camden
#
# [2869 rows x 4 columns]

# %%
url = 'https://www.zoopla.co.uk/for-sale/property/Camden-london-borough/?page_size=25&q=camden&radius=0&results_sort=newest_listings&pn=1'
page = requests.get(url)
bsobj = soup(page.content, 'html5lib')
prueba = []
for j in bsobj.findAll('span',{'data-testid':'date-published'}):
    prueba.append(j.text)
prueba
# Out:
# ['Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 21st Jun 2021',
#  'Listed on 20th Jun 2021',
#  'Listed on 20th Jun 2021',
#  'Listed on 19th Jun 2021',
#  'Listed on 19th Jun 2021']

# %%
df_boroughs['borough_url'][0]
# Out:
# 'https://www.zoopla.co.uk/for-sale/property/Camden-london-borough/?page_size=25&q=camden&radius=0&results_sort=newest_listings&pn=1'

# %%
price = []
for i in bsobj.findAll('div',{'class':'css-wfndrn-StyledContent e2uk8e18'}):
    for j in i.findAll('a', {'class': 'e2uk8e4 css-15tydk8-StyledLink-Link-FullCardLink e33dvwd0'}, href=True):
        price.append(j.get('href'))
    
len(price)
# Out:
# 25
